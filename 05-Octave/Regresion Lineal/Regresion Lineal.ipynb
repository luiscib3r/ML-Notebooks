% %%
load X.dat

% %%
load Y.dat

% %%
whos
% Out:
% Variables in the current scope:
%
%    Attr Name        Size                     Bytes  Class
%    ==== ====        ====                     =====  =====
%         X         506x1                       4048  double
%         Y         506x1                       4048  double
%         ans         1x5                          5  char
%
% Total is 1017 elements using 8101 bytes

% %%
scatter(X, Y)

% %%
o = ones(506, 1);

% %%
X = [o, X];

% %%
whos
% Out:
% Variables in the current scope:
%
%    Attr Name        Size                     Bytes  Class
%    ==== ====        ====                     =====  =====
%         X         506x2                       8096  double
%         Y         506x1                       4048  double
%         ans         1x5                          5  char
%         o         506x1                       4048  double
%
% Total is 2029 elements using 16197 bytes

% %%
X(1,:), X(2,:)
% Out:
% ans =
%
%    1.0000   6.5750
%
% ans =
%
%    1.0000   6.4210

% %%
W = rand(2,1)
% Out:
% W =
%
%    0.72784
%    0.88700

% %%
preds = X*W;

% %%
scatter(X(:,2), Y)
hold on
plot(X(:,2), preds)

% %%
costFunction(X, Y, W)
% Out:
% ans =  170.14

% %%
getGradient(preds, Y, 0.3, X(:,1))
% Out:
% ans = -4.8692

% %%
getGradient(preds, Y, 0.3, X(:,2))
% Out:
% ans = -31.815

% %%
lr = 0.03
% Out:
% lr =  0.030000

% %%
for i=1:100000,
    preds = X*W;
    W(1) = W(1) - getGradient(preds, Y, lr, X(:,1));
    W(2) = W(2) - getGradient(preds, Y, lr, X(:,2));
end;

% %%
costFunction(X, Y, W)
% Out:
% ans =  21.800

% %%
preds = X*W;
scatter(X(:,2), Y)
hold on
plot(X(:,2), preds)
